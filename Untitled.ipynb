# %%
from dash import Dash, html
import pymongo
import pandas as pd

# %%
mongo_conn_str = "mongodb+srv://kennethr:jldWyszwZi8bRtsN@data-main.ubaxa5i.mongodb.net/data_main"
mongo_client = pymongo.MongoClient(mongo_conn_str).get_database("mqtt").RawSignals
signals = mongo_client.find()
data = pd.DataFrame(list(signals))

# %%
data.plot()
# Out:
# <Axes: >
